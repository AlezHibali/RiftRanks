# %%
import json
import os
import pandas as pd

def process_json_files(directory_path):
    # Initialize a DataFrame to store the results for all files
    df_all_results = pd.DataFrame()
    
    # Loop over each JSON file in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            with open(os.path.join(directory_path, filename), 'r') as file:
                loaded_data = json.load(file)

                # Filter out the required events from loaded_data
                champion_kill_events = [event for event in loaded_data if event.get('eventType', '') == 'champion_kill']
                ward_killed_events = [event for event in loaded_data if event.get('eventType', '') == 'ward_killed']
                ward_placed_events = [event for event in loaded_data if event.get('eventType', '') == 'ward_placed']

                # Process champion_kill events
                kill_counts = {}
                victim_counts = {}
                for event in champion_kill_events:
                    killer = event.get('killer')
                    victim = event.get('victim')
                    if killer:
                        kill_counts[killer] = kill_counts.get(killer, 0) + 1
                    if victim:
                        victim_counts[victim] = victim_counts.get(victim, 0) + 1

                # Process ward_killed events
                ward_killed_counts = {}
                for event in ward_killed_events:
                    killer = event.get('killer')
                    if killer:
                        ward_killed_counts[killer] = ward_killed_counts.get(killer, 0) + 1

                # Process ward_placed events
                ward_placed_counts = {}
                for event in ward_placed_events:
                    placer = event.get('placer')
                    if placer:
                        ward_placed_counts[placer] = ward_placed_counts.get(placer, 0) + 1

                # Create a DataFrame for this file
                unique_player_ids = set(kill_counts.keys()) | set(victim_counts.keys()) | set(ward_killed_counts.keys()) | set(ward_placed_counts.keys())
                data = []
                for player_id in unique_player_ids:
                    data.append([
                        champion_kill_events[0]['platformGameId'],
                        player_id,
                        kill_counts.get(player_id, 0),
                        victim_counts.get(player_id, 0),
                        ward_killed_counts.get(player_id, 0),
                        ward_placed_counts.get(player_id, 0)
                    ])

                df_file = pd.DataFrame(data, columns=['platformGameId', 'playerID', 'killCount', 'victimCount', 'wardKilledCount', 'wardPlacedCount'])
                
                # Append the DataFrame for this file to the overall results DataFrame
                df_all_results = pd.concat([df_all_results, df_file], ignore_index=True)

    return df_all_results

# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO

S3_BUCKET_URL = "https://power-rankings-dataset-gprhack.s3.us-west-2.amazonaws.com"

def download_gzip_and_write_to_json(file_name):
    local_file_name = file_name.replace(":", "_")
    # If file already exists locally do not re-download game
    if os.path.isfile(f"{local_file_name}.json"):
        return

    response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
    if response.status_code == 200:
        try:
            gzip_bytes = BytesIO(response.content)
            with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
                with open(f"{local_file_name}.json", 'wb') as output_file:
                    shutil.copyfileobj(gzipped_file, output_file)
                print(f"{file_name}.json written")
        except Exception as e:
            print("Error:", e)
    else:
        print(f"Failed to download {file_name}")

def download_esports_files():
    directory = "esports-data"
    if not os.path.exists(directory):
        os.makedirs(directory)

    esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data"]
    for file_name in esports_data_files:
        download_gzip_and_write_to_json(f"{directory}/{file_name}")

def download_games(year):
    start_time = time.time()
    game_number = 100
    master_df = pd.DataFrame()
    with open("esports-data/tournaments.json", "r") as json_file:
        tournaments_data = json.load(json_file)
    with open("esports-data/mapping_data.json", "r") as json_file:
        mappings_data = json.load(json_file)

    directory = "games"
    if not os.path.exists(directory):
        os.makedirs(directory)

    mappings = {
        esports_game["esportsGameId"]: esports_game for esports_game in mappings_data
    }

    game_counter = 0
    int_game_counter = 0

    for tournament in tournaments_data:
        start_date = tournament.get("startDate", "")
        if start_date.startswith(str(year)):
            print(f"Processing {tournament['slug']}")
            for stage in tournament["stages"]:
                for section in stage["sections"]:
                    for match in section["matches"]:
                        for game in match["games"]:
                            if game["state"] == "completed":
                                try:
                                    platform_game_id = mappings[game["id"]]["platformGameId"]
                                except KeyError:
                                    print(f"{game['id']} not found in the mapping table")
                                    continue

                                download_gzip_and_write_to_json(f"{directory}/{platform_game_id}")
                                game_counter += 1
                                int_game_counter += 1
                            
                            # Exit condition once max_games have been processed
                            if int_game_counter >= game_number:
                                int_game_counter = 0 
                                directory_of_deleted = "C:\\data for lol\\code\\games"
                                master_df = pd.concat([master_df, process_json_files(directory_of_deleted)], ignore_index=True)
                                print("data process complete\n")
                                for filename in os.listdir(directory_of_deleted):
                                    file_path = os.path.join(directory_of_deleted, filename)
                                    
                                    # Check if it's a file
                                    if os.path.isfile(file_path):
                                        os.remove(file_path)  # Delete the file
                                print("data delete complete\n")

                            if game_counter % 10 == 0:
                                print(
                                    f"----- Processed {game_counter} games, current run time: \
                                    {round((time.time() - start_time)/60, 2)} minutes"
                                )
                            # if game_counter > max_game: 
                            #     print("1000 complete\n")
                            #     master_df.to_csv("C:\\data for lol\\result chart\\master_consolidated_data.csv", index=False)
                                # return
                                        
                                
    master_df.to_csv("C:\\data for lol\\result chart\\master_consolidated_data.csv", index=False)

if __name__ == "__main__":
    download_esports_files()
    download_games(2023)
# Out:
# esports-data/leagues.json written
# esports-data/tournaments.json written
# esports-data/players.json written
# esports-data/teams.json written
# esports-data/mapping_data.json written
# Processing nacl_qualifiers_2_summer_2023
# games/ESPORTSTMNT03:3196037.json written
# games/ESPORTSTMNT03:3196049.json written
# games/ESPORTSTMNT03:3196058.json written
# games/ESPORTSTMNT03:3197014.json written
# games/ESPORTSTMNT03:3198185.json written
# games/ESPORTSTMNT03:3200156.json written
# games/ESPORTSTMNT03:3199178.json written
# games/ESPORTSTMNT03:3198199.json written
# games/ESPORTSTMNT03:3200168.json written
# games/ESPORTSTMNT03:3198544.json written
# ----- Processed 10 games, current run time:                                     0.32 minutes
# games/ESPORTSTMNT03:3198546.json written
# games/ESPORTSTMNT03:3195064.json written
# games/ESPORTSTMNT03:3196051.json written
# games/ESPORTSTMNT03:3196057.json written
# 110733838936446954 not found in the mapping table
# games/ESPORTSTMNT03:3197025.json written
# games/ESPORTSTMNT03:3198183.json written
# games/ESPORTSTMNT03:3199172.json written
# games/ESPORTSTMNT03:3198196.json written
# games/ESPORTSTMNT03:3200165.json written
# games/ESPORTSTMNT03:3198206.json written
# ----- Processed 20 games, current run time:                                     0.58 minutes
# games/ESPORTSTMNT03:3198553.json written
# games/ESPORTSTMNT03:3199526.json written
# games/ESPORTSTMNT03:3199528.json written
# games/ESPORTSTMNT03:3195262.json written
# games/ESPORTSTMNT03:3197195.json written
# games/ESPORTSTMNT03:3197205.json written
# games/ESPORTSTMNT03:3195300.json written
# games/ESPORTSTMNT03:3198294.json written
# games/ESPORTSTMNT03:3199274.json written
# games/ESPORTSTMNT03:3198298.json written
# ----- Processed 30 games, current run time:                                     0.91 minutes
# games/ESPORTSTMNT03:3198299.json written
# games/ESPORTSTMNT03:3200543.json written
# games/ESPORTSTMNT03:3199525.json written
# games/ESPORTSTMNT03:3197182.json written
# games/ESPORTSTMNT03:3195276.json written
# games/ESPORTSTMNT03:3195306.json written
# games/ESPORTSTMNT03:3196275.json written
# games/ESPORTSTMNT03:3198292.json written
# games/ESPORTSTMNT03:3198296.json written
# 110733838936447001 not found in the mapping table
# 110733838936447002 not found in the mapping table
# games/ESPORTSTMNT03:3200536.json written
# ----- Processed 40 games, current run time:                                     1.2 minutes
# games/ESPORTSTMNT03:3200539.json written
# games/ESPORTSTMNT03:3199520.json written
# games/ESPORTSTMNT03:3198611.json written
# games/ESPORTSTMNT03:3200605.json written
# games/ESPORTSTMNT03:3198621.json written
# games/ESPORTSTMNT03:3200613.json written
# games/ESPORTSTMNT03:3200614.json written
# games/ESPORTSTMNT03:3198612.json written
# games/ESPORTSTMNT03:3200607.json written
# games/ESPORTSTMNT03:3200609.json written
# ----- Processed 50 games, current run time:                                     1.47 minutes
# games/ESPORTSTMNT03:3198622.json written
# games/ESPORTSTMNT03:3198623.json written
# games/ESPORTSTMNT03:3198727.json written
# games/ESPORTSTMNT03:3198737.json written
# games/ESPORTSTMNT03:3199703.json written
# games/ESPORTSTMNT03:3198740.json written
# games/ESPORTSTMNT03:3200718.json written
# games/ESPORTSTMNT03:3198741.json written
# games/ESPORTSTMNT03:3198743.json written
# games/ESPORTSTMNT03:3200722.json written
# ----- Processed 60 games, current run time:                                     1.75 minutes
# games/ESPORTSTMNT03:3198744.json written
# Processing gll_summer_2023
# games/ESPORTSTMNT01:3383508.json written
# games/ESPORTSTMNT03:3166207.json written
# games/ESPORTSTMNT03:3166463.json written
# games/ESPORTSTMNT01:3369750.json written
# games/ESPORTSTMNT01:3373407.json written
# games/ESPORTSTMNT03:3166786.json written
# games/ESPORTSTMNT01:3385039.json written
# games/ESPORTSTMNT01:3370824.json written
# games/ESPORTSTMNT03:3165797.json written
# ----- Processed 70 games, current run time:                                     2.04 minutes
# games/ESPORTSTMNT03:3167447.json written
# games/ESPORTSTMNT01:3383851.json written
# games/ESPORTSTMNT01:3374235.json written
# games/ESPORTSTMNT03:3167097.json written
# games/ESPORTSTMNT01:3382983.json written
# games/ESPORTSTMNT03:3165885.json written
# games/ESPORTSTMNT03:3166491.json written
# games/ESPORTSTMNT01:3383466.json written
# games/ESPORTSTMNT01:3372328.json written
# games/ESPORTSTMNT01:3373365.json written
# ----- Processed 80 games, current run time:                                     2.39 minutes
# games/ESPORTSTMNT01:3382512.json written
# games/ESPORTSTMNT03:3166149.json written
# games/ESPORTSTMNT01:3369698.json written
# games/ESPORTSTMNT03:3166123.json written
# games/ESPORTSTMNT01:3385015.json written
# games/ESPORTSTMNT01:3384405.json written
# games/ESPORTSTMNT01:3371651.json written
# games/ESPORTSTMNT03:3165840.json written
# games/ESPORTSTMNT03:3167347.json written
# games/ESPORTSTMNT01:3390879.json written
# ----- Processed 90 games, current run time:                                     2.74 minutes
# games/ESPORTSTMNT03:3185548.json written
# games/ESPORTSTMNT03:3184143.json written
# games/ESPORTSTMNT03:3176620.json written
# games/ESPORTSTMNT03:3176286.json written
# games/ESPORTSTMNT03:3180760.json written
# games/ESPORTSTMNT01:3389698.json written
# games/ESPORTSTMNT03:3174697.json written
# 110428723805336981 not found in the mapping table
# games/ESPORTSTMNT03:3185169.json written
# games/ESPORTSTMNT01:3390584.json written
# games/ESPORTSTMNT03:3176207.json written
# data process complete
#
# data delete complete
#
# ----- Processed 100 games, current run time:                                     5.17 minutes
# games/ESPORTSTMNT03:3185523.json written
# games/ESPORTSTMNT01:3390621.json written
# games/ESPORTSTMNT03:3182799.json written
# games/ESPORTSTMNT03:3185130.json written
# games/ESPORTSTMNT01:3391036.json written
# games/ESPORTSTMNT03:3176234.json written
# games/ESPORTSTMNT03:3176263.json written
# games/ESPORTSTMNT01:3389839.json written
# games/ESPORTSTMNT03:3184549.json written
# games/ESPORTSTMNT03:3174629.json written
# ----- Processed 110 games, current run time:                                     5.56 minutes
# games/ESPORTSTMNT03:3183492.json written
# games/ESPORTSTMNT01:3388808.json written
# games/ESPORTSTMNT01:3390833.json written
# games/ESPORTSTMNT03:3176526.json written
# games/ESPORTSTMNT03:3182739.json written
# games/ESPORTSTMNT03:3184119.json written
# games/ESPORTSTMNT03:3191737.json written
# games/ESPORTSTMNT03:3190842.json written
# games/ESPORTSTMNT03:3189910.json written
# games/ESPORTSTMNT03:3191822.json written
# ----- Processed 120 games, current run time:                                     5.89 minutes
# games/ESPORTSTMNT03:3190919.json written
# games/ESPORTSTMNT06:2822208.json written
# games/ESPORTSTMNT06:2822219.json written
# games/ESPORTSTMNT06:2822222.json written
# games/ESPORTSTMNT03:3195550.json written
# games/ESPORTSTMNT03:3195570.json written
# games/ESPORTSTMNT03:3197538.json written
# games/ESPORTSTMNT03:3195598.json written
# games/ESPORTSTMNT01:3407892.json written
# games/ESPORTSTMNT01:3409803.json written
# ----- Processed 130 games, current run time:                                     6.19 minutes
# games/ESPORTSTMNT01:3409822.json written
# games/ESPORTSTMNT01:3408868.json written
# games/ESPORTSTMNT01:3409862.json written
# Processing elite_series_summer_2023
# games/ESPORTSTMNT04:2683951.json written
# games/ESPORTSTMNT04:2684716.json written
# games/ESPORTSTMNT04:2683305.json written
# games/ESPORTSTMNT04:2685161.json written
# games/ESPORTSTMNT03:3165542.json written
# games/ESPORTSTMNT04:2687267.json written
# games/ESPORTSTMNT06:2815913.json written
# ----- Processed 140 games, current run time:                                     6.46 minutes
# games/ESPORTSTMNT04:2683130.json written
# games/ESPORTSTMNT06:2815885.json written
# games/ESPORTSTMNT04:2683276.json written
# games/ESPORTSTMNT04:2687281.json written
# games/ESPORTSTMNT04:2683788.json written
# games/ESPORTSTMNT03:3167423.json written
# games/ESPORTSTMNT04:2687237.json written
# games/ESPORTSTMNT03:3166521.json written
# games/ESPORTSTMNT04:2685298.json written
# games/ESPORTSTMNT06:2817904.json written
# ----- Processed 150 games, current run time:                                     6.82 minutes
# games/ESPORTSTMNT04:2683967.json written
# games/ESPORTSTMNT04:2685748.json written
# games/ESPORTSTMNT04:2685917.json written
# games/ESPORTSTMNT03:3165613.json written
# games/ESPORTSTMNT04:2685151.json written
# games/ESPORTSTMNT06:2816865.json written
# games/ESPORTSTMNT04:2684919.json written
# games/ESPORTSTMNT04:2686273.json written
# games/ESPORTSTMNT04:2683108.json written
# games/ESPORTSTMNT04:2684736.json written
# ----- Processed 160 games, current run time:                                     7.12 minutes
# games/ESPORTSTMNT04:2683289.json written
# games/ESPORTSTMNT06:2823164.json written
# games/ESPORTSTMNT06:2818761.json written
# games/ESPORTSTMNT06:2818579.json written
# games/ESPORTSTMNT06:2819277.json written
# games/ESPORTSTMNT04:2687428.json written
# games/ESPORTSTMNT06:2821265.json written
# games/ESPORTSTMNT06:2820108.json written
# games/ESPORTSTMNT06:2820286.json written
# games/ESPORTSTMNT06:2819141.json written
# ----- Processed 170 games, current run time:                                     7.4 minutes
# games/ESPORTSTMNT06:2818607.json written
# games/ESPORTSTMNT06:2821256.json written
# games/ESPORTSTMNT06:2820740.json written
# games/ESPORTSTMNT04:2686417.json written
# games/ESPORTSTMNT06:2823263.json written
# games/ESPORTSTMNT04:2688427.json written
# games/ESPORTSTMNT06:2820544.json written
# games/ESPORTSTMNT06:2819124.json written
# games/ESPORTSTMNT06:2822185.json written
# games/ESPORTSTMNT06:2819752.json written
# ----- Processed 180 games, current run time:                                     7.71 minutes
# games/ESPORTSTMNT06:2822181.json written
# games/ESPORTSTMNT04:2686388.json written
# games/ESPORTSTMNT06:2819289.json written
# games/ESPORTSTMNT06:2818134.json written
# games/ESPORTSTMNT06:2823138.json written
# games/ESPORTSTMNT06:2822279.json written
# games/ESPORTSTMNT06:2818303.json written
# games/ESPORTSTMNT06:2819761.json written
# games/ESPORTSTMNT06:2819608.json written
# games/ESPORTSTMNT04:2689598.json written
# ----- Processed 190 games, current run time:                                     7.99 minutes
# games/ESPORTSTMNT04:2691591.json written
# games/ESPORTSTMNT04:2689608.json written
# games/ESPORTSTMNT04:2689710.json written
# games/ESPORTSTMNT04:2689725.json written
# games/ESPORTSTMNT04:2689735.json written
# games/ESPORTSTMNT04:2691729.json written
# games/ESPORTSTMNT04:2691808.json written
# games/ESPORTSTMNT04:2691815.json written
# games/ESPORTSTMNT04:2691820.json written
# games/ESPORTSTMNT04:2689831.json written
# data process complete
#
# data delete complete
#
# ----- Processed 200 games, current run time:                                     10.39 minutes
# ----- Processed 200 games, current run time:                                     10.39 minutes
# games/ESPORTSTMNT04:2693124.json written
# games/ESPORTSTMNT04:2694099.json written
# games/ESPORTSTMNT04:2693144.json written
# 110424377526038830 not found in the mapping table
# Processing superliga_summer_2023
# games/ESPORTSTMNT03:3156536.json written
# games/ESPORTSTMNT03:3158880.json written
# games/ESPORTSTMNT01:3372876.json written
# games/ESPORTSTMNT03:3168052.json written
# games/ESPORTSTMNT03:3160716.json written
# games/ESPORTSTMNT01:3371741.json written
# games/ESPORTSTMNT01:3386275.json written
# ----- Processed 210 games, current run time:                                     10.75 minutes
# games/ESPORTSTMNT01:3382498.json written
# games/ESPORTSTMNT03:3165550.json written
# games/ESPORTSTMNT01:3370821.json written
# games/ESPORTSTMNT03:3158833.json written
# games/ESPORTSTMNT01:3386321.json written
# games/ESPORTSTMNT01:3376001.json written
# games/ESPORTSTMNT03:3169006.json written
# games/ESPORTSTMNT03:3166510.json written
# games/ESPORTSTMNT03:3159874.json written
# games/ESPORTSTMNT01:3384412.json written
# ----- Processed 220 games, current run time:                                     11.07 minutes
# games/ESPORTSTMNT03:3159847.json written
# games/ESPORTSTMNT03:3158441.json written
# games/ESPORTSTMNT01:3383548.json written
# 110349992510530135 not found in the mapping table
# games/ESPORTSTMNT03:3166998.json written
# games/ESPORTSTMNT03:3167472.json written
# games/ESPORTSTMNT01:3385372.json written
# games/ESPORTSTMNT01:3371674.json written
# games/ESPORTSTMNT03:3167349.json written
# games/ESPORTSTMNT01:3383470.json written
# games/ESPORTSTMNT03:3157421.json written
# ----- Processed 230 games, current run time:                                     11.45 minutes
# games/ESPORTSTMNT01:3387182.json written
# games/ESPORTSTMNT03:3167920.json written
# games/ESPORTSTMNT03:3156952.json written
# games/ESPORTSTMNT03:3165605.json written
# games/ESPORTSTMNT01:3382616.json written
# games/ESPORTSTMNT01:3374926.json written
# games/ESPORTSTMNT03:3161590.json written
# games/ESPORTSTMNT01:3387249.json written
# games/ESPORTSTMNT01:3370857.json written
# games/ESPORTSTMNT03:3167959.json written
# ----- Processed 240 games, current run time:                                     11.94 minutes
# games/ESPORTSTMNT03:3157381.json written
# games/ESPORTSTMNT03:3160799.json written
# games/ESPORTSTMNT03:3158304.json written
# games/ESPORTSTMNT03:3158773.json written
# games/ESPORTSTMNT03:3156896.json written
# games/ESPORTSTMNT01:3372943.json written
# games/ESPORTSTMNT01:3369705.json written
# games/ESPORTSTMNT01:3388777.json written
# games/ESPORTSTMNT01:3392067.json written
# games/ESPORTSTMNT03:3184902.json written
# ----- Processed 250 games, current run time:                                     12.35 minutes
# games/ESPORTSTMNT03:3182339.json written
# games/ESPORTSTMNT03:3175234.json written
# games/ESPORTSTMNT03:3185200.json written
# games/ESPORTSTMNT03:3193512.json written
# games/ESPORTSTMNT03:3191746.json written
# games/ESPORTSTMNT03:3179740.json written
# games/ESPORTSTMNT03:3184218.json written
# games/ESPORTSTMNT01:3394040.json written
# games/ESPORTSTMNT03:3194498.json written
# games/ESPORTSTMNT03:3185926.json written
# ----- Processed 260 games, current run time:                                     12.74 minutes
# games/ESPORTSTMNT03:3182294.json written
# games/ESPORTSTMNT03:3178790.json written
# games/ESPORTSTMNT03:3175330.json written
# games/ESPORTSTMNT03:3191846.json written
# games/ESPORTSTMNT03:3175359.json written
# games/ESPORTSTMNT01:3388833.json written
# games/ESPORTSTMNT03:3191817.json written
# games/ESPORTSTMNT03:3185911.json written
# games/ESPORTSTMNT03:3181253.json written
# games/ESPORTSTMNT03:3177878.json written
# ----- Processed 270 games, current run time:                                     13.16 minutes
# games/ESPORTSTMNT03:3194478.json written
# games/ESPORTSTMNT03:3185097.json written
# games/ESPORTSTMNT03:3178770.json written
# games/ESPORTSTMNT03:3189886.json written
# games/ESPORTSTMNT01:3389612.json written
# games/ESPORTSTMNT03:3192559.json written
# games/ESPORTSTMNT03:3181187.json written
# games/ESPORTSTMNT01:3393065.json written
# games/ESPORTSTMNT03:3179818.json written
# games/ESPORTSTMNT03:3190866.json written
# ----- Processed 280 games, current run time:                                     13.49 minutes
# games/ESPORTSTMNT03:3185888.json written
# games/ESPORTSTMNT03:3176242.json written
# games/ESPORTSTMNT03:3192581.json written
# games/ESPORTSTMNT03:3185114.json written
# games/ESPORTSTMNT03:3180228.json written
# games/ESPORTSTMNT01:3388793.json written
# games/ESPORTSTMNT03:3174302.json written
# games/ESPORTSTMNT01:3388819.json written
# games/ESPORTSTMNT04:2688417.json written
# games/ESPORTSTMNT01:3393061.json written
# ----- Processed 290 games, current run time:                                     13.78 minutes
# games/ESPORTSTMNT03:3184919.json written
# games/ESPORTSTMNT03:3185137.json written
# games/ESPORTSTMNT03:3192630.json written
# games/ESPORTSTMNT04:2691340.json written
# games/ESPORTSTMNT04:2690331.json written
# games/ESPORTSTMNT04:2691359.json written
# games/ESPORTSTMNT01:3399644.json written
# games/ESPORTSTMNT01:3398675.json written
# games/ESPORTSTMNT01:3398688.json written
# games/ESPORTSTMNT01:3399681.json written
# data process complete
#
# data delete complete
#
# ----- Processed 300 games, current run time:                                     16.49 minutes
# ----- Processed 300 games, current run time:                                     16.49 minutes
# games/ESPORTSTMNT04:2689260.json written
# games/ESPORTSTMNT04:2689267.json written
# games/ESPORTSTMNT04:2691261.json written
# games/ESPORTSTMNT04:2690267.json written
# games/ESPORTSTMNT04:2691581.json written
# games/ESPORTSTMNT04:2690569.json written
# games/ESPORTSTMNT04:2689603.json written
# games/ESPORTSTMNT04:2691595.json written
# games/ESPORTSTMNT04:2690583.json written
# games/ESPORTSTMNT04:2691692.json written
# ----- Processed 310 games, current run time:                                     16.9 minutes
# games/ESPORTSTMNT04:2689715.json written
# games/ESPORTSTMNT04:2690685.json written
# games/ESPORTSTMNT04:2690696.json written
# games/ESPORTSTMNT04:2692183.json written
# games/ESPORTSTMNT04:2693170.json written
# games/ESPORTSTMNT04:2692188.json written
# games/ESPORTSTMNT04:2694139.json written
# Processing ultraliga_summer_2023
# games/ESPORTSTMNT04:2685686.json written
# games/ESPORTSTMNT06:2815779.json written
# games/ESPORTSTMNT06:2816418.json written
# ----- Processed 320 games, current run time:                                     17.29 minutes
# games/ESPORTSTMNT04:2683186.json written
# games/ESPORTSTMNT04:2684808.json written
# games/ESPORTSTMNT04:2684109.json written
# games/ESPORTSTMNT06:2816464.json written
# games/ESPORTSTMNT06:2816814.json written
# games/ESPORTSTMNT06:2815384.json written
# games/ESPORTSTMNT06:2816358.json written
# games/ESPORTSTMNT06:2816445.json written
# games/ESPORTSTMNT06:2817810.json written
# games/ESPORTSTMNT06:2817751.json written
# ----- Processed 330 games, current run time:                                     17.59 minutes
# games/ESPORTSTMNT06:2817410.json written
# games/ESPORTSTMNT04:2683165.json written
# games/ESPORTSTMNT04:2684100.json written
# games/ESPORTSTMNT04:2685838.json written
# games/ESPORTSTMNT04:2684764.json written
# games/ESPORTSTMNT04:2685823.json written
# games/ESPORTSTMNT06:2815825.json written
# games/ESPORTSTMNT04:2685857.json written
# games/ESPORTSTMNT04:2683137.json written
# games/ESPORTSTMNT06:2815418.json written
# ----- Processed 340 games, current run time:                                     17.88 minutes
# games/ESPORTSTMNT06:2816474.json written
# games/ESPORTSTMNT06:2817395.json written
# games/ESPORTSTMNT04:2685122.json written
# games/ESPORTSTMNT06:2815737.json written
# games/ESPORTSTMNT06:2816781.json written
# games/ESPORTSTMNT04:2683838.json written
# games/ESPORTSTMNT04:2685178.json written
# games/ESPORTSTMNT06:2817475.json written
# games/ESPORTSTMNT04:2684682.json written
# games/ESPORTSTMNT06:2816408.json written
# ----- Processed 350 games, current run time:                                     18.2 minutes
# games/ESPORTSTMNT06:2816736.json written
# games/ESPORTSTMNT04:2683125.json written
# games/ESPORTSTMNT06:2815376.json written
# games/ESPORTSTMNT04:2684711.json written
# games/ESPORTSTMNT04:2683208.json written
# games/ESPORTSTMNT06:2815400.json written
# games/ESPORTSTMNT04:2683827.json written
# games/ESPORTSTMNT06:2816453.json written
# games/ESPORTSTMNT06:2816810.json written
# games/ESPORTSTMNT06:2816346.json written
# ----- Processed 360 games, current run time:                                     18.51 minutes
# games/ESPORTSTMNT06:2816754.json written
# games/ESPORTSTMNT04:2683757.json written
# games/ESPORTSTMNT06:2821132.json written
# games/ESPORTSTMNT06:2819664.json written
# games/ESPORTSTMNT04:2686224.json written
# games/ESPORTSTMNT06:2818544.json written
# games/ESPORTSTMNT06:2821255.json written
# games/ESPORTSTMNT04:2687325.json written
# games/ESPORTSTMNT06:2818085.json written
# games/ESPORTSTMNT06:2822221.json written
# ----- Processed 370 games, current run time:                                     18.81 minutes
# games/ESPORTSTMNT06:2820214.json written
# games/ESPORTSTMNT06:2818191.json written
# games/ESPORTSTMNT06:2819119.json written
# games/ESPORTSTMNT06:2821195.json written
# games/ESPORTSTMNT06:2818665.json written
# games/ESPORTSTMNT04:2687238.json written
# games/ESPORTSTMNT06:2818560.json written
# games/ESPORTSTMNT04:2686326.json written
# games/ESPORTSTMNT06:2821266.json written
# games/ESPORTSTMNT06:2821173.json written
# ----- Processed 380 games, current run time:                                     19.29 minutes
# games/ESPORTSTMNT06:2821243.json written
# games/ESPORTSTMNT06:2822205.json written
# games/ESPORTSTMNT06:2820534.json written
# games/ESPORTSTMNT04:2686307.json written
# games/ESPORTSTMNT04:2688292.json written
# games/ESPORTSTMNT06:2819130.json written
# games/ESPORTSTMNT06:2818204.json written
# games/ESPORTSTMNT04:2688323.json written
# games/ESPORTSTMNT06:2819642.json written
# games/ESPORTSTMNT06:2822237.json written
# ----- Processed 390 games, current run time:                                     19.58 minutes
# games/ESPORTSTMNT06:2822261.json written
# games/ESPORTSTMNT03:3183232.json written
# games/ESPORTSTMNT06:2820136.json written
# games/ESPORTSTMNT06:2821128.json written
# games/ESPORTSTMNT04:2687262.json written
# games/ESPORTSTMNT06:2818639.json written
# games/ESPORTSTMNT04:2687307.json written
# games/ESPORTSTMNT06:2820184.json written
# games/ESPORTSTMNT06:2823144.json written
# games/ESPORTSTMNT06:2819594.json written
# data process complete
# data delete complete
#
# ----- Processed 400 games, current run time:                                     22.06 minutes
# games/ESPORTSTMNT04:2688231.json written
# games/ESPORTSTMNT06:2823255.json written
# games/ESPORTSTMNT06:2818103.json written
# games/ESPORTSTMNT06:2821217.json written
# games/ESPORTSTMNT06:2820223.json written
# games/ESPORTSTMNT06:2820641.json written
# games/ESPORTSTMNT06:2823165.json written
# games/ESPORTSTMNT04:2689588.json written
# games/ESPORTSTMNT04:2689599.json written
# games/ESPORTSTMNT04:2690570.json written
# ----- Processed 410 games, current run time:                                     22.47 minutes
# games/ESPORTSTMNT04:2690574.json written
# games/ESPORTSTMNT04:2689609.json written
# games/ESPORTSTMNT04:2691159.json written
# games/ESPORTSTMNT04:2690161.json written
# games/ESPORTSTMNT04:2690164.json written
# games/ESPORTSTMNT04:2691177.json written
# games/ESPORTSTMNT04:2690242.json written
# games/ESPORTSTMNT04:2691250.json written
# games/ESPORTSTMNT04:2691258.json written
# games/ESPORTSTMNT04:2689635.json written
# ----- Processed 420 games, current run time:                                     22.77 minutes
# games/ESPORTSTMNT04:2690615.json written
# games/ESPORTSTMNT04:2689647.json written
# games/ESPORTSTMNT04:2690626.json written
# games/ESPORTSTMNT04:2690729.json written
# games/ESPORTSTMNT04:2689775.json written
# games/ESPORTSTMNT04:2690748.json written
# games/ESPORTSTMNT04:2690755.json written
# games/ESPORTSTMNT04:2692175.json written
# games/ESPORTSTMNT04:2693161.json written
# games/ESPORTSTMNT04:2693169.json written
# ----- Processed 430 games, current run time:                                     23.14 minutes
# ----- Processed 430 games, current run time:                                     23.14 minutes
# ----- Processed 430 games, current run time:                                     23.14 minutes
# Processing lpl_regional_finals_2023
# games/LPL_A:343930.json written
# games/LPL_A:343936.json written
# games/LPL_A:343937.json written
# games/LPL_A:342859.json written
# games/LPL_A:342874.json written
# games/LPL_A:342884.json written
# games/LPL_A:343971.json written
# games/LPL_A:343972.json written
# games/LPL_A:342885.json written
# games/LPL_A:343990.json written
# ----- Processed 440 games, current run time:                                     23.52 minutes
# games/LPL_A:343995.json written
# games/LPL_A:343996.json written
# games/LPL_A:342907.json written
# Processing tcl_summer_2023
# games/ESPORTSTMNT04:2683217.json written
# games/ESPORTSTMNT04:2686009.json written
# games/ESPORTSTMNT04:2684942.json written
# games/ESPORTSTMNT04:2688490.json written
# games/ESPORTSTMNT04:2685274.json written
# games/ESPORTSTMNT04:2686368.json written
# games/ESPORTSTMNT04:2685359.json written
# ----- Processed 450 games, current run time:                                     23.81 minutes
# games/ESPORTSTMNT04:2687377.json written
# games/ESPORTSTMNT04:2684391.json written
# 110429898578758443 not found in the mapping table
# games/ESPORTSTMNT04:2685885.json written
# games/ESPORTSTMNT04:2686476.json written
# games/ESPORTSTMNT04:2687015.json written
# games/ESPORTSTMNT04:2688474.json written
# games/ESPORTSTMNT04:2684415.json written
# games/ESPORTSTMNT04:2685180.json written
# games/ESPORTSTMNT04:2685902.json written
# games/ESPORTSTMNT04:2683274.json written
# ----- Processed 460 games, current run time:                                     24.11 minutes
# games/ESPORTSTMNT04:2683206.json written
# games/ESPORTSTMNT04:2685982.json written
# games/ESPORTSTMNT04:2683302.json written
# games/ESPORTSTMNT04:2687405.json written
# games/ESPORTSTMNT04:2687421.json written
# games/ESPORTSTMNT04:2685970.json written
# games/ESPORTSTMNT04:2683927.json written
# games/ESPORTSTMNT04:2683407.json written
# games/ESPORTSTMNT04:2687488.json written
# games/ESPORTSTMNT04:2684205.json written
# ----- Processed 470 games, current run time:                                     24.46 minutes
# games/ESPORTSTMNT06:2818300.json written
# games/ESPORTSTMNT06:2820861.json written
# games/ESPORTSTMNT06:2818717.json written
# games/ESPORTSTMNT06:2822307.json written
# games/ESPORTSTMNT06:2820334.json written
# games/ESPORTSTMNT06:2823281.json written
# games/ESPORTSTMNT06:2819647.json written
# games/ESPORTSTMNT06:2821251.json written
# games/ESPORTSTMNT06:2820649.json written
# games/ESPORTSTMNT06:2819332.json written
# ----- Processed 480 games, current run time:                                     24.83 minutes
# games/ESPORTSTMNT06:2818742.json written
# games/ESPORTSTMNT06:2822313.json written
# games/ESPORTSTMNT06:2820876.json written
# games/ESPORTSTMNT06:2823306.json written
# games/ESPORTSTMNT06:2820673.json written
# games/ESPORTSTMNT06:2818260.json written
# games/ESPORTSTMNT06:2818750.json written
# games/ESPORTSTMNT06:2818344.json written
# games/ESPORTSTMNT06:2818291.json written
# games/ESPORTSTMNT06:2820845.json written
# ----- Processed 490 games, current run time:                                     25.11 minutes
# games/ESPORTSTMNT06:2819359.json written
# games/ESPORTSTMNT06:2823258.json written
# games/ESPORTSTMNT06:2822259.json written
# games/ESPORTSTMNT06:2820833.json written
# games/ESPORTSTMNT06:2818728.json written
# games/ESPORTSTMNT06:2820664.json written
# games/ESPORTSTMNT06:2823327.json written
# games/ESPORTSTMNT06:2818276.json written
# games/ESPORTSTMNT04:2691337.json written
# games/ESPORTSTMNT04:2689361.json written
# data process complete
# data delete complete
#
# ----- Processed 500 games, current run time:                                     27.61 minutes
# games/ESPORTSTMNT04:2690336.json written
# games/ESPORTSTMNT04:2689379.json written
# games/ESPORTSTMNT04:2689168.json written
# games/ESPORTSTMNT04:2690165.json written
# games/ESPORTSTMNT04:2691176.json written
# games/ESPORTSTMNT04:2689186.json written
# games/ESPORTSTMNT04:2690188.json written
# games/ESPORTSTMNT04:2689259.json written
# games/ESPORTSTMNT04:2690257.json written
# games/ESPORTSTMNT04:2689274.json written
# ----- Processed 510 games, current run time:                                     28.0 minutes
# games/ESPORTSTMNT04:2689283.json written
# games/ESPORTSTMNT04:2690272.json written
# games/ESPORTSTMNT04:2690733.json written
# games/ESPORTSTMNT04:2690749.json written
# games/ESPORTSTMNT04:2690751.json written
# games/ESPORTSTMNT04:2690847.json written
# games/ESPORTSTMNT04:2691896.json written
# games/ESPORTSTMNT04:2689888.json written
# games/ESPORTSTMNT04:2691905.json written
# games/ESPORTSTMNT04:2692163.json written
# ----- Processed 520 games, current run time:                                     28.38 minutes
# games/ESPORTSTMNT04:2692177.json written
# games/ESPORTSTMNT04:2694131.json written
# games/ESPORTSTMNT04:2692186.json written
# Processing nlc_summer_2023
# games/ESPORTSTMNT06:2817841.json written
# games/ESPORTSTMNT04:2683728.json written
# games/ESPORTSTMNT04:2685190.json written
# games/ESPORTSTMNT04:2686269.json written
# games/ESPORTSTMNT06:2816755.json written
# games/ESPORTSTMNT04:2684848.json written
# games/ESPORTSTMNT04:2685106.json written
# ----- Processed 530 games, current run time:                                     28.7 minutes
# games/ESPORTSTMNT04:2684124.json written
# games/ESPORTSTMNT04:2685815.json written
# games/ESPORTSTMNT04:2684240.json written
# games/ESPORTSTMNT04:2683760.json written
# games/ESPORTSTMNT06:2815768.json written
# games/ESPORTSTMNT04:2687242.json written
# games/ESPORTSTMNT03:3166758.json written
# games/ESPORTSTMNT03:3167426.json written
# games/ESPORTSTMNT04:2685177.json written
# games/ESPORTSTMNT04:2688241.json written
# ----- Processed 540 games, current run time:                                     29.0 minutes
# games/ESPORTSTMNT04:2685825.json written
# games/ESPORTSTMNT04:2685141.json written
# games/ESPORTSTMNT04:2687269.json written
# games/ESPORTSTMNT04:2683715.json written
# games/ESPORTSTMNT06:2816720.json written
# games/ESPORTSTMNT04:2684819.json written
# games/ESPORTSTMNT06:2815813.json written
# games/ESPORTSTMNT04:2683779.json written
# games/ESPORTSTMNT04:2683141.json written
# games/ESPORTSTMNT06:2815843.json written
# ----- Processed 550 games, current run time:                                     29.29 minutes
# games/ESPORTSTMNT04:2684230.json written
# games/ESPORTSTMNT06:2818123.json written
# games/ESPORTSTMNT06:2819686.json written
# games/ESPORTSTMNT06:2820564.json written
# games/ESPORTSTMNT03:3192255.json written
# games/ESPORTSTMNT04:2686305.json written
# games/ESPORTSTMNT03:3191802.json written
# games/ESPORTSTMNT06:2819186.json written
# games/ESPORTSTMNT06:2818203.json written
# games/ESPORTSTMNT03:3191775.json written
# ----- Processed 560 games, current run time:                                     29.63 minutes
# games/ESPORTSTMNT06:2818591.json written
# games/ESPORTSTMNT06:2818661.json written
# games/ESPORTSTMNT04:2687321.json written
# games/ESPORTSTMNT03:3193237.json written
# games/ESPORTSTMNT06:2818135.json written
# games/ESPORTSTMNT04:2687338.json written
# games/ESPORTSTMNT06:2818545.json written
# games/ESPORTSTMNT03:3193284.json written
# games/ESPORTSTMNT03:3191834.json written
# games/ESPORTSTMNT06:2818219.json written
# ----- Processed 570 games, current run time:                                     29.96 minutes
# games/ESPORTSTMNT03:3192300.json written
# games/ESPORTSTMNT06:2820647.json written
# games/ESPORTSTMNT04:2686333.json written
# games/ESPORTSTMNT03:3190809.json written
# games/ESPORTSTMNT06:2819100.json written
# games/ESPORTSTMNT06:2820648.json written
# games/ESPORTSTMNT06:2820224.json written
# games/ESPORTSTMNT06:2818109.json written
# games/ESPORTSTMNT06:2819595.json written
# games/ESPORTSTMNT01:3399650.json written
# ----- Processed 580 games, current run time:                                     30.3 minutes
# games/ESPORTSTMNT01:3399660.json written
# games/ESPORTSTMNT01:3400717.json written
# games/ESPORTSTMNT01:3400731.json written
# games/ESPORTSTMNT01:3398713.json written
# games/ESPORTSTMNT01:3402119.json written
# games/ESPORTSTMNT01:3402139.json written
# games/ESPORTSTMNT01:3403138.json written
# games/ESPORTSTMNT01:3402167.json written
# games/ESPORTSTMNT01:3406716.json written
# games/ESPORTSTMNT01:3404825.json written
# ----- Processed 590 games, current run time:                                     30.61 minutes
# games/ESPORTSTMNT01:3405817.json written
# games/ESPORTSTMNT01:3409799.json written
# games/ESPORTSTMNT01:3407933.json written
# games/ESPORTSTMNT01:3409853.json written
# games/ESPORTSTMNT01:3409867.json written
# Processing ljl_academy_2023
# games/ESPORTSTMNT01:3385191.json written
# games/ESPORTSTMNT01:3384669.json written
# games/ESPORTSTMNT02:3213193.json written
# games/ESPORTSTMNT01:3383758.json written
# games/ESPORTSTMNT01:3387112.json written
# data process complete
# data delete complete
#
# ----- Processed 600 games, current run time:                                     33.09 minutes
# games/ESPORTSTMNT02:3214420.json written
# games/ESPORTSTMNT02:3215095.json written
# games/ESPORTSTMNT02:3213181.json written
# games/ESPORTSTMNT01:3382780.json written
# games/ESPORTSTMNT02:3213150.json written
# games/ESPORTSTMNT02:3214401.json written
# games/ESPORTSTMNT01:3387109.json written
# games/ESPORTSTMNT01:3384750.json written
# games/ESPORTSTMNT01:3386189.json written
# games/ESPORTSTMNT01:3386154.json written
# ----- Processed 610 games, current run time:                                     33.43 minutes
# games/ESPORTSTMNT01:3384650.json written
# games/ESPORTSTMNT02:3214119.json written
# games/ESPORTSTMNT02:3215410.json written
# games/ESPORTSTMNT02:3215431.json written
# games/ESPORTSTMNT02:3215112.json written
# games/ESPORTSTMNT01:3382882.json written
# games/ESPORTSTMNT01:3387089.json written
# games/ESPORTSTMNT01:3384670.json written
# games/ESPORTSTMNT02:3213194.json written
# games/ESPORTSTMNT01:3387074.json written
# ----- Processed 620 games, current run time:                                     33.72 minutes
# games/ESPORTSTMNT01:3386190.json written
# games/ESPORTSTMNT02:3214141.json written
# games/ESPORTSTMNT01:3384719.json written
# games/ESPORTSTMNT02:3219314.json written
# games/ESPORTSTMNT02:3218695.json written
# games/ESPORTSTMNT02:3220213.json written
# games/ESPORTSTMNT02:3218671.json written
# games/ESPORTSTMNT02:3219313.json written
# games/ESPORTSTMNT02:3219652.json written
# games/ESPORTSTMNT02:3213495.json written
# ----- Processed 630 games, current run time:                                     34.0 minutes
# games/ESPORTSTMNT02:3221152.json written
# games/ESPORTSTMNT02:3217756.json written
# games/ESPORTSTMNT02:3215444.json written
# games/ESPORTSTMNT02:3220234.json written
# games/ESPORTSTMNT02:3217869.json written
# games/ESPORTSTMNT02:3218696.json written
# games/ESPORTSTMNT02:3217866.json written
# games/ESPORTSTMNT02:3217855.json written
# games/ESPORTSTMNT02:3217757.json written
# games/ESPORTSTMNT02:3213506.json written
# ----- Processed 640 games, current run time:                                     34.27 minutes
# games/ESPORTSTMNT02:3221177.json written
# games/ESPORTSTMNT02:3220222.json written
# games/ESPORTSTMNT02:3215460.json written
# games/ESPORTSTMNT02:3221270.json written
# games/ESPORTSTMNT02:3219295.json written
# games/ESPORTSTMNT02:3218703.json written
# games/ESPORTSTMNT02:3220232.json written
# games/ESPORTSTMNT02:3218812.json written
# games/ESPORTSTMNT02:3219311.json written
# games/ESPORTSTMNT02:3221159.json written
# ----- Processed 650 games, current run time:                                     34.67 minutes
# games/ESPORTSTMNT02:3219189.json written
# games/ESPORTSTMNT03:3194055.json written
# games/ESPORTSTMNT02:3220351.json written
# games/ESPORTSTMNT03:3192507.json written
# games/ESPORTSTMNT02:3221294.json written
# games/ESPORTSTMNT03:3193148.json written
# games/ESPORTSTMNT03:3196653.json written
# games/ESPORTSTMNT03:3192487.json written
# games/ESPORTSTMNT03:3192506.json written
# games/ESPORTSTMNT02:3221296.json written
# ----- Processed 660 games, current run time:                                     34.95 minutes
# games/ESPORTSTMNT03:3193448.json written
# 110507407706737220 not found in the mapping table
# games/ESPORTSTMNT03:3192198.json written
# games/ESPORTSTMNT02:3220327.json written
# games/ESPORTSTMNT03:3192182.json written
# games/ESPORTSTMNT03:3193157.json written
# games/ESPORTSTMNT02:3219745.json written
# games/ESPORTSTMNT03:3192492.json written
# games/ESPORTSTMNT03:3197639.json written
# games/ESPORTSTMNT03:3197633.json written
# games/ESPORTSTMNT03:3192491.json written
# ----- Processed 670 games, current run time:                                     35.29 minutes
# games/ESPORTSTMNT02:3219214.json written
# games/ESPORTSTMNT03:3194090.json written
# games/ESPORTSTMNT02:3220330.json written
# games/ESPORTSTMNT03:3194357.json written
# games/ESPORTSTMNT03:3194065.json written
# games/ESPORTSTMNT03:3193123.json written
# games/ESPORTSTMNT03:3194358.json written
# games/ESPORTSTMNT02:3220352.json written
# games/ESPORTSTMNT01:3404970.json written
# games/ESPORTSTMNT01:3406900.json written
# ----- Processed 680 games, current run time:                                     35.63 minutes
# ----- Processed 680 games, current run time:                                     35.63 minutes
# games/ESPORTSTMNT01:3409129.json written
# games/ESPORTSTMNT01:3409145.json written
# games/ESPORTSTMNT01:3413093.json written
# games/ESPORTSTMNT01:3414074.json written
# games/ESPORTSTMNT01:3413113.json written
# games/ESPORTSTMNT01:3413117.json written
# games/ESPORTSTMNT01:3415035.json written
# Processing pg_nationals_summer_2023
# games/ESPORTSTMNT01:3376460.json written
# games/ESPORTSTMNT01:3387218.json written
# games/ESPORTSTMNT03:3166997.json written
# ----- Processed 690 games, current run time:                                     35.96 minutes
# games/ESPORTSTMNT04:2686427.json written
# games/ESPORTSTMNT01:3373930.json written
# games/ESPORTSTMNT01:3385667.json written
# games/ESPORTSTMNT03:3169171.json written
# games/ESPORTSTMNT01:3375024.json written
# games/ESPORTSTMNT01:3387483.json written
# games/ESPORTSTMNT01:3385384.json written
# games/ESPORTSTMNT03:3169019.json written
# games/ESPORTSTMNT03:3168266.json written
# games/ESPORTSTMNT04:2686394.json written
# data process complete
# data delete complete
#
# ----- Processed 700 games, current run time:                                     38.36 minutes
# games/ESPORTSTMNT04:2686414.json written
# games/ESPORTSTMNT01:3386574.json written
# games/ESPORTSTMNT03:3170102.json written
# games/ESPORTSTMNT01:3378426.json written
# games/ESPORTSTMNT03:3168095.json written
# games/ESPORTSTMNT03:3169174.json written
# games/ESPORTSTMNT01:3385374.json written
# games/ESPORTSTMNT01:3374944.json written
# games/ESPORTSTMNT01:3376408.json written
# games/ESPORTSTMNT01:3376495.json written
# ----- Processed 710 games, current run time:                                     38.69 minutes
# games/ESPORTSTMNT03:3166984.json written
# games/ESPORTSTMNT01:3372960.json written
# games/ESPORTSTMNT04:2686404.json written
# games/ESPORTSTMNT01:3385675.json written
# games/ESPORTSTMNT01:3385401.json written
# games/ESPORTSTMNT03:3185870.json written
# games/ESPORTSTMNT03:3187278.json written
# games/ESPORTSTMNT04:2688491.json written
# games/ESPORTSTMNT03:3192853.json written
# games/ESPORTSTMNT03:3178436.json written
# ----- Processed 720 games, current run time:                                     39.0 minutes
# games/ESPORTSTMNT03:3193572.json written
# games/ESPORTSTMNT03:3178090.json written
# games/ESPORTSTMNT03:3177416.json written
# games/ESPORTSTMNT03:3193540.json written
# games/ESPORTSTMNT03:3188230.json written
# games/ESPORTSTMNT04:2686473.json written
# games/ESPORTSTMNT03:3177024.json written
# games/ESPORTSTMNT03:3193783.json written
# games/ESPORTSTMNT03:3194767.json written
# games/ESPORTSTMNT03:3194450.json written
# ----- Processed 730 games, current run time:                                     39.27 minutes
# games/ESPORTSTMNT03:3179007.json written
# games/ESPORTSTMNT03:3185904.json written
# games/ESPORTSTMNT04:2688517.json written
# games/ESPORTSTMNT03:3179035.json written
# games/ESPORTSTMNT03:3188282.json written
# games/ESPORTSTMNT03:3177449.json written
# games/ESPORTSTMNT03:3185887.json written
# games/ESPORTSTMNT03:3183968.json written
# games/ESPORTSTMNT04:2688511.json written
# games/ESPORTSTMNT03:3177394.json written
# ----- Processed 740 games, current run time:                                     39.56 minutes
# games/ESPORTSTMNT03:3192826.json written
# games/ESPORTSTMNT03:3192595.json written
# games/ESPORTSTMNT03:3187295.json written
# games/ESPORTSTMNT01:3402143.json written
# games/ESPORTSTMNT01:3401168.json written
# games/ESPORTSTMNT01:3401189.json written
# games/ESPORTSTMNT01:3403176.json written
# games/ESPORTSTMNT01:3402292.json written
# games/ESPORTSTMNT01:3403318.json written
# games/ESPORTSTMNT01:3401351.json written
# ----- Processed 750 games, current run time:                                     39.99 minutes
# games/ESPORTSTMNT01:3401362.json written
# games/ESPORTSTMNT01:3404485.json written
# games/ESPORTSTMNT01:3405461.json written
# games/ESPORTSTMNT01:3404510.json written
# games/ESPORTSTMNT01:3408822.json written
# games/ESPORTSTMNT01:3408852.json written
# games/ESPORTSTMNT01:3409839.json written
# games/ESPORTSTMNT01:3408875.json written
# Processing ebl_summer_2023
# games/ESPORTSTMNT06:2816901.json written
# games/ESPORTSTMNT04:2684289.json written
# ----- Processed 760 games, current run time:                                     40.29 minutes
# games/ESPORTSTMNT04:2687023.json written
# games/ESPORTSTMNT04:2685390.json written
# games/ESPORTSTMNT06:2816848.json written
# games/ESPORTSTMNT06:2815840.json written
# games/ESPORTSTMNT04:2683933.json written
# games/ESPORTSTMNT06:2817829.json written
# games/ESPORTSTMNT04:2684324.json written
# games/ESPORTSTMNT04:2687004.json written
# games/ESPORTSTMNT04:2683955.json written
# games/ESPORTSTMNT06:2817895.json written
# ----- Processed 770 games, current run time:                                     40.65 minutes
# games/ESPORTSTMNT04:2683408.json written
# games/ESPORTSTMNT04:2685948.json written
# games/ESPORTSTMNT06:2817903.json written
# games/ESPORTSTMNT04:2686017.json written
# games/ESPORTSTMNT04:2685373.json written
# games/ESPORTSTMNT06:2815937.json written
# games/ESPORTSTMNT06:2815859.json written
# games/ESPORTSTMNT04:2683429.json written
# games/ESPORTSTMNT06:2817942.json written
# games/ESPORTSTMNT06:2815912.json written
# ----- Processed 780 games, current run time:                                     40.96 minutes
# games/ESPORTSTMNT06:2816891.json written
# games/ESPORTSTMNT04:2683905.json written
# games/ESPORTSTMNT04:2684340.json written
# games/ESPORTSTMNT04:2684309.json written
# games/ESPORTSTMNT06:2815828.json written
# games/ESPORTSTMNT04:2686001.json written
# games/ESPORTSTMNT06:2823231.json written
# games/ESPORTSTMNT01:3394060.json written
# games/ESPORTSTMNT06:2819877.json written
# games/ESPORTSTMNT01:3391402.json written
# ----- Processed 790 games, current run time:                                     41.25 minutes
# games/ESPORTSTMNT06:2819748.json written
# games/ESPORTSTMNT06:2823334.json written
# games/ESPORTSTMNT06:2822258.json written
# games/ESPORTSTMNT06:2823329.json written
# games/ESPORTSTMNT01:3391265.json written
# games/ESPORTSTMNT06:2818879.json written
# games/ESPORTSTMNT06:2821264.json written
# games/ESPORTSTMNT06:2819770.json written
# games/ESPORTSTMNT01:3394184.json written
# games/ESPORTSTMNT06:2823288.json written
# data process complete
# data delete complete
#
# ----- Processed 800 games, current run time:                                     43.66 minutes
# games/ESPORTSTMNT06:2820752.json written
# games/ESPORTSTMNT06:2820844.json written
# games/ESPORTSTMNT01:3394190.json written
# games/ESPORTSTMNT06:2821207.json written
# games/ESPORTSTMNT06:2822305.json written
# games/ESPORTSTMNT01:3391381.json written
# games/ESPORTSTMNT06:2823222.json written
# games/ESPORTSTMNT06:2818726.json written
# games/ESPORTSTMNT06:2821226.json written
# games/ESPORTSTMNT06:2823272.json written
# ----- Processed 810 games, current run time:                                     44.12 minutes
# games/ESPORTSTMNT04:2687402.json written
# games/ESPORTSTMNT04:2686379.json written
# games/ESPORTSTMNT06:2821295.json written
# games/ESPORTSTMNT06:2819855.json written
# games/ESPORTSTMNT04:2691249.json written
# games/ESPORTSTMNT04:2691260.json written
# games/ESPORTSTMNT04:2689275.json written
# games/ESPORTSTMNT04:2691276.json written
# games/ESPORTSTMNT04:2691334.json written
# games/ESPORTSTMNT04:2689363.json written
# ----- Processed 820 games, current run time:                                     44.74 minutes
# games/ESPORTSTMNT04:2689370.json written
# games/ESPORTSTMNT04:2689542.json written
# games/ESPORTSTMNT04:2691532.json written
# games/ESPORTSTMNT04:2690524.json written
# games/ESPORTSTMNT04:2691540.json written
# games/ESPORTSTMNT04:2694130.json written
# games/ESPORTSTMNT04:2693168.json written
# games/ESPORTSTMNT04:2693171.json written
# games/ESPORTSTMNT04:2693173.json written
# Processing lrs_closing_2023
# games/ESPORTSTMNT01:3366083.json written
# ----- Processed 830 games, current run time:                                     45.04 minutes
# games/ESPORTSTMNT01:3379197.json written
# games/ESPORTSTMNT02:3208800.json written
# games/ESPORTSTMNT03:3164523.json written
# games/ESPORTSTMNT03:3159919.json written
# games/ESPORTSTMNT01:3376095.json written
# games/ESPORTSTMNT01:3364786.json written
# games/ESPORTSTMNT01:3378505.json written
# games/ESPORTSTMNT03:3163203.json written
# games/ESPORTSTMNT03:3162675.json written
# games/ESPORTSTMNT01:3375060.json written
# ----- Processed 840 games, current run time:                                     45.46 minutes
# games/ESPORTSTMNT02:3209854.json written
# games/ESPORTSTMNT03:3163249.json written
# games/ESPORTSTMNT01:3363718.json written
# games/ESPORTSTMNT03:3160836.json written
# games/ESPORTSTMNT01:3380108.json written
# games/ESPORTSTMNT01:3375656.json written
# games/ESPORTSTMNT01:3365747.json written
# games/ESPORTSTMNT01:3375177.json written
# games/ESPORTSTMNT01:3375691.json written
# games/ESPORTSTMNT03:3159943.json written
# ----- Processed 850 games, current run time:                                     46.07 minutes
# games/ESPORTSTMNT03:3163226.json written
# games/ESPORTSTMNT02:3207841.json written
# games/ESPORTSTMNT01:3367113.json written
# games/ESPORTSTMNT03:3160861.json written
# games/ESPORTSTMNT01:3381042.json written
# games/ESPORTSTMNT01:3375674.json written
# games/ESPORTSTMNT01:3367147.json written
# games/ESPORTSTMNT03:3163239.json written
# games/ESPORTSTMNT03:3164534.json written
# games/ESPORTSTMNT01:3366106.json written
# ----- Processed 860 games, current run time:                                     46.62 minutes
# games/ESPORTSTMNT03:3162278.json written
# games/ESPORTSTMNT01:3378466.json written
# games/ESPORTSTMNT01:3364704.json written
# games/ESPORTSTMNT01:3379177.json written
# games/ESPORTSTMNT03:3163616.json written
# games/ESPORTSTMNT02:3209811.json written
# 110372454558363028 not found in the mapping table
# games/ESPORTSTMNT01:3363735.json written
# games/ESPORTSTMNT01:3380184.json written
# games/ESPORTSTMNT01:3368099.json written
# games/ESPORTSTMNT02:3208850.json written
# ----- Processed 870 games, current run time:                                     47.49 minutes
# games/ESPORTSTMNT03:3162684.json written
# games/ESPORTSTMNT01:3375163.json written
# games/ESPORTSTMNT03:3160809.json written
# games/ESPORTSTMNT03:3177476.json written
# games/ESPORTSTMNT03:3193652.json written
# games/ESPORTSTMNT03:3192896.json written
# games/ESPORTSTMNT02:3216456.json written
# games/ESPORTSTMNT02:3210045.json written
# games/ESPORTSTMNT03:3186064.json written
# games/ESPORTSTMNT03:3178226.json written
# ----- Processed 880 games, current run time:                                     48.0 minutes
# games/ESPORTSTMNT03:3187376.json written
# games/ESPORTSTMNT02:3216116.json written
# games/ESPORTSTMNT02:3213912.json written
# games/ESPORTSTMNT03:3185990.json written
# games/ESPORTSTMNT03:3193864.json written
# games/ESPORTSTMNT02:3216159.json written
# games/ESPORTSTMNT03:3177154.json written
# games/ESPORTSTMNT02:3212031.json written
# games/ESPORTSTMNT03:3192633.json written
# games/ESPORTSTMNT03:3187400.json written
# ----- Processed 890 games, current run time:                                     48.52 minutes
# games/ESPORTSTMNT03:3179173.json written
# games/ESPORTSTMNT03:3186099.json written
# games/ESPORTSTMNT03:3188410.json written
# games/ESPORTSTMNT02:3210077.json written
# games/ESPORTSTMNT02:3214598.json written
# games/ESPORTSTMNT03:3193877.json written
# games/ESPORTSTMNT03:3179521.json written
# games/ESPORTSTMNT02:3212056.json written
# games/ESPORTSTMNT03:3193617.json written
# games/ESPORTSTMNT03:3186464.json written
# data process complete
#
# data delete complete
#
# ----- Processed 900 games, current run time:                                     51.35 minutes
# games/ESPORTSTMNT03:3177584.json written
# games/ESPORTSTMNT02:3213657.json written
# games/ESPORTSTMNT02:3213974.json written
# games/ESPORTSTMNT03:3178511.json written
# games/ESPORTSTMNT02:3214567.json written
# games/ESPORTSTMNT03:3188307.json written
# games/ESPORTSTMNT03:3178116.json written
# games/ESPORTSTMNT03:3192670.json written
# games/ESPORTSTMNT02:3216484.json written
# games/ESPORTSTMNT03:3192885.json written
# ----- Processed 910 games, current run time:                                     51.72 minutes
# games/ESPORTSTMNT03:3186009.json written
# games/ESPORTSTMNT03:3178178.json written
# games/ESPORTSTMNT03:3194593.json written
# games/ESPORTSTMNT03:3177570.json written
# games/ESPORTSTMNT03:3192937.json written
# games/ESPORTSTMNT02:3216439.json written
# games/ESPORTSTMNT03:3187069.json written
# ...
# games/ESPORTSTMNT02:3158520.json written
# games/ESPORTSTMNT03:3099031.json written
# games/ESPORTSTMNT03:3098143.json written
# ----- Processed 7450 games, current run time:                                     418.73 minutes
# ----- Processed 7450 games, current run time:                                     418.73 minutes
# games/ESPORTSTMNT01:3315349.json written
# games/ESPORTSTMNT01:3316259.json written
# 109672513960335282 not found in the mapping table
# games/ESPORTSTMNT03:3091513.json written
# games/ESPORTSTMNT03:3091532.json written
# games/ESPORTSTMNT01:3328958.json written
# games/ESPORTSTMNT01:3328968.json written
# games/ESPORTSTMNT01:3328976.json written
# games/ESPORTSTMNT01:3323952.json written
# games/ESPORTSTMNT01:3321972.json written
# games/ESPORTSTMNT01:3321978.json written
# ----- Processed 7460 games, current run time:                                     419.21 minutes
# games/ESPORTSTMNT01:3323975.json written
# games/ESPORTSTMNT01:3326211.json written
# games/ESPORTSTMNT01:3325232.json written
# games/ESPORTSTMNT01:3326230.json written
# games/ESPORTSTMNT01:3325255.json written
# games/ESPORTSTMNT01:3326254.json written
# games/ESPORTSTMNT01:3333801.json written
# games/ESPORTSTMNT01:3335726.json written
# games/ESPORTSTMNT01:3333811.json written
# games/ESPORTSTMNT01:3333820.json written
# ----- Processed 7470 games, current run time:                                     419.63 minutes
# games/ESPORTSTMNT01:3335749.json written
# games/ESPORTSTMNT01:3330266.json written
# games/ESPORTSTMNT01:3331239.json written
# games/ESPORTSTMNT01:3332255.json written
# games/ESPORTSTMNT01:3331246.json written
# games/ESPORTSTMNT01:3338036.json written
# games/ESPORTSTMNT01:3337072.json written
# games/ESPORTSTMNT01:3336144.json written
# games/ESPORTSTMNT01:3337087.json written
# games/ESPORTSTMNT01:3338064.json written
# ----- Processed 7480 games, current run time:                                     420.27 minutes
# games/ESPORTSTMNT01:3340421.json written
# games/ESPORTSTMNT01:3341409.json written
# games/ESPORTSTMNT01:3341415.json written
# games/ESPORTSTMNT01:3340438.json written
# games/ESPORTSTMNT01:3342594.json written
# games/ESPORTSTMNT01:3342595.json written
# games/ESPORTSTMNT01:3344541.json written
# games/ESPORTSTMNT01:3343549.json written
# 109672513960335334 not found in the mapping table
# Processing pg_nationals_spring_2023
# games/ESPORTSTMNT03:3098449.json written
# games/ESPORTSTMNT03:3092118.json written
# ----- Processed 7490 games, current run time:                                     420.8 minutes
# games/ESPORTSTMNT02:3170395.json written
# games/ESPORTSTMNT03:3098827.json written
# games/ESPORTSTMNT03:3089806.json written
# games/ESPORTSTMNT01:3316440.json written
# games/ESPORTSTMNT02:3169161.json written
# games/ESPORTSTMNT02:3171378.json written
# games/ESPORTSTMNT03:3090682.json written
# games/ESPORTSTMNT01:3316510.json written
# games/ESPORTSTMNT03:3094075.json written
# games/ESPORTSTMNT02:3170083.json written
# data process complete
# data delete complete
#
# ----- Processed 7500 games, current run time:                                     423.45 minutes
# games/ESPORTSTMNT03:3100742.json written
# games/ESPORTSTMNT03:3100728.json written
# games/ESPORTSTMNT03:3099366.json written
# games/ESPORTSTMNT02:3169150.json written
# games/ESPORTSTMNT03:3091672.json written
# games/ESPORTSTMNT01:3316459.json written
# games/ESPORTSTMNT02:3170118.json written
# games/ESPORTSTMNT01:3315605.json written
# games/ESPORTSTMNT03:3100324.json written
# games/ESPORTSTMNT03:3094049.json written
# ----- Processed 7510 games, current run time:                                     423.93 minutes
# games/ESPORTSTMNT02:3169390.json written
# games/ESPORTSTMNT03:3092100.json written
# games/ESPORTSTMNT01:3297245.json written
# games/ESPORTSTMNT03:3099692.json written
# games/ESPORTSTMNT03:3098435.json written
# games/ESPORTSTMNT02:3170350.json written
# games/ESPORTSTMNT02:3160621.json written
# games/ESPORTSTMNT02:3161066.json written
# games/ESPORTSTMNT03:3124323.json written
# games/ESPORTSTMNT02:3170582.json written
# ----- Processed 7520 games, current run time:                                     424.35 minutes
# games/ESPORTSTMNT01:3317684.json written
# games/ESPORTSTMNT03:3125776.json written
# games/ESPORTSTMNT03:3120860.json written
# games/ESPORTSTMNT03:3123305.json written
# games/ESPORTSTMNT01:3317696.json written
# games/ESPORTSTMNT03:3125808.json written
# games/ESPORTSTMNT02:3161006.json written
# games/ESPORTSTMNT03:3122731.json written
# games/ESPORTSTMNT02:3169606.json written
# games/ESPORTSTMNT02:3170603.json written
# ----- Processed 7530 games, current run time:                                     424.78 minutes
# games/ESPORTSTMNT02:3161630.json written
# games/ESPORTSTMNT03:3122803.json written
# games/ESPORTSTMNT01:3316688.json written
# games/ESPORTSTMNT03:3124859.json written
# games/ESPORTSTMNT03:3121793.json written
# games/ESPORTSTMNT03:3123852.json written
# games/ESPORTSTMNT02:3161535.json written
# games/ESPORTSTMNT02:3162005.json written
# games/ESPORTSTMNT03:3124350.json written
# games/ESPORTSTMNT02:3161035.json written
# ----- Processed 7540 games, current run time:                                     425.11 minutes
# games/ESPORTSTMNT01:3317673.json written
# games/ESPORTSTMNT02:3171548.json written
# games/ESPORTSTMNT02:3160711.json written
# games/ESPORTSTMNT03:3123273.json written
# games/ESPORTSTMNT03:3129412.json written
# games/ESPORTSTMNT03:3129421.json written
# games/ESPORTSTMNT03:3131362.json written
# games/ESPORTSTMNT03:3130386.json written
# games/ESPORTSTMNT03:3130544.json written
# games/ESPORTSTMNT03:3129599.json written
# ----- Processed 7550 games, current run time:                                     425.46 minutes
# games/ESPORTSTMNT03:3130557.json written
# games/ESPORTSTMNT03:3131559.json written
# games/ESPORTSTMNT01:3330740.json written
# games/ESPORTSTMNT01:3331690.json written
# games/ESPORTSTMNT01:3331706.json written
# games/ESPORTSTMNT01:3331729.json written
# games/ESPORTSTMNT01:3336673.json written
# games/ESPORTSTMNT01:3337587.json written
# games/ESPORTSTMNT01:3336729.json written
# games/ESPORTSTMNT01:3337609.json written
# ----- Processed 7560 games, current run time:                                     425.84 minutes
# games/ESPORTSTMNT01:3338635.json written
# Processing cblol_2023_split_1
# games/ESPORTSTMNT01:3300699.json written
# games/ESPORTSTMNT01:3313248.json written
# games/ESPORTSTMNT03:3094757.json written
# games/ESPORTSTMNT03:3086706.json written
# games/ESPORTSTMNT03:3087532.json written
# games/ESPORTSTMNT03:3092417.json written
# games/ESPORTSTMNT01:3302258.json written
# games/ESPORTSTMNT02:3153877.json written
# games/ESPORTSTMNT01:3311651.json written
# ----- Processed 7570 games, current run time:                                     426.19 minutes
# games/ESPORTSTMNT03:3087692.json written
# games/ESPORTSTMNT01:3302316.json written
# games/ESPORTSTMNT03:3093417.json written
# games/ESPORTSTMNT02:3153825.json written
# games/ESPORTSTMNT03:3092815.json written
# games/ESPORTSTMNT01:3309743.json written
# games/ESPORTSTMNT01:3313202.json written
# games/ESPORTSTMNT03:3088580.json written
# games/ESPORTSTMNT03:3092442.json written
# games/ESPORTSTMNT03:3092740.json written
# ----- Processed 7580 games, current run time:                                     426.55 minutes
# games/ESPORTSTMNT01:3300434.json written
# games/ESPORTSTMNT01:3311744.json written
# games/ESPORTSTMNT01:3300727.json written
# games/ESPORTSTMNT03:3087549.json written
# games/ESPORTSTMNT02:3151911.json written
# games/ESPORTSTMNT03:3086486.json written
# games/ESPORTSTMNT01:3311712.json written
# games/ESPORTSTMNT03:3086700.json written
# games/ESPORTSTMNT02:3153897.json written
# games/ESPORTSTMNT01:3301792.json written
# ----- Processed 7590 games, current run time:                                     426.98 minutes
# games/ESPORTSTMNT01:3313115.json written
# games/ESPORTSTMNT01:3302641.json written
# games/ESPORTSTMNT02:3151939.json written
# games/ESPORTSTMNT01:3313274.json written
# games/ESPORTSTMNT01:3309691.json written
# games/ESPORTSTMNT01:3300413.json written
# games/ESPORTSTMNT01:3312216.json written
# games/ESPORTSTMNT03:3094708.json written
# games/ESPORTSTMNT03:3086653.json written
# games/ESPORTSTMNT03:3094421.json written
# data process complete
# data delete complete
#
# ----- Processed 7600 games, current run time:                                     429.53 minutes
# games/ESPORTSTMNT03:3087499.json written
# games/ESPORTSTMNT01:3301406.json written
# games/ESPORTSTMNT01:3302674.json written
# games/ESPORTSTMNT03:3094402.json written
# games/ESPORTSTMNT03:3087701.json written
# games/ESPORTSTMNT03:3092796.json written
# games/ESPORTSTMNT03:3126234.json written
# games/ESPORTSTMNT01:3328068.json written
# games/ESPORTSTMNT03:3114975.json written
# games/ESPORTSTMNT02:3164695.json written
# ----- Processed 7610 games, current run time:                                     429.95 minutes
# games/ESPORTSTMNT02:3154270.json written
# games/ESPORTSTMNT02:3166049.json written
# games/ESPORTSTMNT03:3117452.json written
# games/ESPORTSTMNT01:3328379.json written
# games/ESPORTSTMNT03:3127554.json written
# games/ESPORTSTMNT02:3163733.json written
# games/ESPORTSTMNT03:3118326.json written
# games/ESPORTSTMNT02:3165985.json written
# games/ESPORTSTMNT01:3328411.json written
# games/ESPORTSTMNT03:3116931.json written
# ----- Processed 7620 games, current run time:                                     430.3 minutes
# games/ESPORTSTMNT03:3126561.json written
# games/ESPORTSTMNT01:3328094.json written
# games/ESPORTSTMNT02:3154297.json written
# games/ESPORTSTMNT02:3168056.json written
# games/ESPORTSTMNT03:3114863.json written
# games/ESPORTSTMNT03:3117421.json written
# games/ESPORTSTMNT03:3128544.json written
# games/ESPORTSTMNT03:3128240.json written
# games/ESPORTSTMNT02:3155254.json written
# games/ESPORTSTMNT01:3327386.json written
# ----- Processed 7630 games, current run time:                                     430.62 minutes
# games/ESPORTSTMNT02:3154355.json written
# games/ESPORTSTMNT03:3126529.json written
# games/ESPORTSTMNT02:3163681.json written
# games/ESPORTSTMNT01:3328298.json written
# games/ESPORTSTMNT03:3126254.json written
# games/ESPORTSTMNT01:3328079.json written
# games/ESPORTSTMNT03:3126281.json written
# games/ESPORTSTMNT01:3329301.json written
# games/ESPORTSTMNT01:3329040.json written
# games/ESPORTSTMNT03:3126579.json written
# ----- Processed 7640 games, current run time:                                     430.99 minutes
# games/ESPORTSTMNT03:3119387.json written
# games/ESPORTSTMNT01:3328015.json written
# games/ESPORTSTMNT03:3116979.json written
# games/ESPORTSTMNT02:3165582.json written
# games/ESPORTSTMNT02:3168031.json written
# games/ESPORTSTMNT02:3154330.json written
# games/ESPORTSTMNT03:3117387.json written
# games/ESPORTSTMNT03:3127162.json written
# games/ESPORTSTMNT02:3167106.json written
# games/ESPORTSTMNT02:3164616.json written
# ----- Processed 7650 games, current run time:                                     431.29 minutes
# games/ESPORTSTMNT03:3114925.json written
# games/ESPORTSTMNT01:3332679.json written
# games/ESPORTSTMNT01:3332704.json written
# games/ESPORTSTMNT01:3331687.json written
# games/ESPORTSTMNT01:3330970.json written
# games/ESPORTSTMNT01:3331934.json written
# games/ESPORTSTMNT01:3333009.json written
# games/ESPORTSTMNT01:3335145.json written
# games/ESPORTSTMNT01:3334178.json written
# games/ESPORTSTMNT01:3333240.json written
# ----- Processed 7660 games, current run time:                                     431.71 minutes
# games/ESPORTSTMNT01:3334191.json written
# games/ESPORTSTMNT01:3336956.json written
# games/ESPORTSTMNT01:3338904.json written
# games/ESPORTSTMNT01:3336977.json written
# games/ESPORTSTMNT01:3338918.json written
# games/ESPORTSTMNT01:3337903.json written
# games/ESPORTSTMNT01:3339169.json written
# games/ESPORTSTMNT01:3339186.json written
# games/ESPORTSTMNT01:3341080.json written
# games/ESPORTSTMNT01:3340115.json written
# ----- Processed 7670 games, current run time:                                     432.05 minutes
# ----- Processed 7670 games, current run time:                                     432.05 minutes
# games/ESPORTSTMNT01:3342132.json written
# games/ESPORTSTMNT01:3342148.json written
# games/ESPORTSTMNT01:3344078.json written
# games/ESPORTSTMNT01:3343177.json written
# games/ESPORTSTMNT01:3344199.json written
# games/ESPORTSTMNT01:3343196.json written
# games/ESPORTSTMNT01:3344212.json written
# games/ESPORTSTMNT01:3344227.json written
# games/ESPORTSTMNT01:3342624.json written
# games/ESPORTSTMNT01:3344571.json written
# ----- Processed 7680 games, current run time:                                     432.41 minutes
# games/ESPORTSTMNT01:3344573.json written
# Processing arabian_league_spring_2023
# games/ESPORTSTMNT03:3098830.json written
# games/ESPORTSTMNT01:3306704.json written
# games/ESPORTSTMNT01:3307039.json written
# games/ESPORTSTMNT01:3310290.json written
# games/ESPORTSTMNT01:3316205.json written
# games/ESPORTSTMNT03:3100388.json written
# games/ESPORTSTMNT03:3096856.json written
# games/ESPORTSTMNT01:3317175.json written
# games/ESPORTSTMNT01:3306621.json written
# ----- Processed 7690 games, current run time:                                     432.75 minutes
# games/ESPORTSTMNT03:3100359.json written
# games/ESPORTSTMNT01:3307101.json written
# games/ESPORTSTMNT03:3097984.json written
# games/ESPORTSTMNT01:3310160.json written
# games/ESPORTSTMNT01:3311155.json written
# games/ESPORTSTMNT03:3098049.json written
# games/ESPORTSTMNT03:3098400.json written
# games/ESPORTSTMNT01:3306190.json written
# games/ESPORTSTMNT03:3098787.json written
# games/ESPORTSTMNT01:3315287.json written
# data process complete
#
# data delete complete
#
# ----- Processed 7700 games, current run time:                                     435.4 minutes
# games/ESPORTSTMNT03:3096934.json written
# games/ESPORTSTMNT03:3098754.json written
# games/ESPORTSTMNT03:3099260.json written
# games/ESPORTSTMNT03:3098808.json written
# games/ESPORTSTMNT01:3307711.json written
# games/ESPORTSTMNT01:3307204.json written
# games/ESPORTSTMNT01:3311199.json written
# games/ESPORTSTMNT01:3306660.json written
# games/ESPORTSTMNT01:3317087.json written
# games/ESPORTSTMNT02:3162591.json written
# ----- Processed 7710 games, current run time:                                     435.66 minutes
# games/ESPORTSTMNT02:3169391.json written
# games/ESPORTSTMNT02:3171010.json written
# games/ESPORTSTMNT02:3171593.json written
# games/ESPORTSTMNT03:3122736.json written
# games/ESPORTSTMNT02:3160076.json written
# games/ESPORTSTMNT01:3317430.json written
# games/ESPORTSTMNT03:3122828.json written
# games/ESPORTSTMNT02:3171294.json written
# games/ESPORTSTMNT02:3161015.json written
# games/ESPORTSTMNT02:3171047.json written
# ----- Processed 7720 games, current run time:                                     435.98 minutes
# games/ESPORTSTMNT01:3317459.json written
# games/ESPORTSTMNT02:3169605.json written
# games/ESPORTSTMNT02:3170550.json written
# games/ESPORTSTMNT01:3315570.json written
# games/ESPORTSTMNT02:3159876.json written
# games/ESPORTSTMNT02:3170141.json written
# games/ESPORTSTMNT02:3162498.json written
# games/ESPORTSTMNT03:3122705.json written
# games/ESPORTSTMNT01:3317362.json written
# games/ESPORTSTMNT02:3161506.json written
# ----- Processed 7730 games, current run time:                                     436.39 minutes
# games/ESPORTSTMNT02:3159815.json written
# games/ESPORTSTMNT02:3161608.json written
# games/ESPORTSTMNT02:3171366.json written
# games/ESPORTSTMNT02:3171080.json written
# games/ESPORTSTMNT02:3171555.json written
# games/ESPORTSTMNT02:3170360.json written
# games/ESPORTSTMNT03:3121798.json written
# games/ESPORTSTMNT03:3125238.json written
# games/ESPORTSTMNT03:3123299.json written
# games/ESPORTSTMNT03:3123316.json written
# ----- Processed 7740 games, current run time:                                     436.81 minutes
# games/ESPORTSTMNT03:3123372.json written
# games/ESPORTSTMNT03:3130163.json written
# games/ESPORTSTMNT03:3130191.json written
# games/ESPORTSTMNT03:3129242.json written
# games/ESPORTSTMNT03:3131179.json written
# games/ESPORTSTMNT03:3131334.json written
# games/ESPORTSTMNT03:3130362.json written
# games/ESPORTSTMNT03:3130372.json written
# games/ESPORTSTMNT01:3338275.json written
# games/ESPORTSTMNT01:3337298.json written
# ----- Processed 7750 games, current run time:                                     437.17 minutes
# games/ESPORTSTMNT01:3337315.json written

# %%
import csv
import json
import pandas as pd

# Read the CSV file
with open("C:\\data for lol\\result chart\\master_consolidated_data.csv", 'r', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    csv_data = list(csv_reader)

# Read the mapping data from the JSON file
with open("C:\\data for lol\\esports-data\\mapping_data.json", 'r', encoding='utf-8') as json_file:
    mapping_data = json.load(json_file)

# Create a dictionary for faster lookup of participantMapping based on platformGameId
platform_game_id_to_mapping = {entry['platformGameId']: entry['participantMapping'] for entry in mapping_data}

# Add the "participantMapping" column to the CSV data
for row in csv_data:
    platform_game_id = row['platformGameId']
    player_id = row['playerID']
    if platform_game_id in platform_game_id_to_mapping:
        row['participantMapping'] = platform_game_id_to_mapping[platform_game_id].get(player_id, None)
    else:
        row['participantMapping'] = None

# Convert the updated CSV data to a pandas DataFrame
df_updated_csv = pd.DataFrame(csv_data)

# Read the players data from the JSON file
with open("C:\\data for lol\\esports-data\\players.json", 'r', encoding='utf-8') as json_file:
    players_data = json.load(json_file)

# Create a dictionary for faster lookup of handle based on player_id
player_id_to_handle = {entry['player_id']: entry['handle'] for entry in players_data}

# Add the "handle" column to the CSV data
df_updated_csv['handle'] = df_updated_csv['participantMapping'].map(player_id_to_handle)

# Group by "handle" and concatenate platformGameId values with commas
grouped_platform_game_ids = df_updated_csv.groupby('handle')['platformGameId'].apply(lambda x: ','.join(x)).reset_index()

# Convert the columns to numeric type for aggregation
numeric_columns = ['killCount', 'victimCount', 'wardKilledCount', 'wardPlacedCount']
df_updated_csv[numeric_columns] = df_updated_csv[numeric_columns].apply(pd.to_numeric)

# Aggregate the columns by summing them for each handle
grouped_df = df_updated_csv.groupby('handle').agg({
    'killCount': 'sum',
    'victimCount': 'sum',
    'wardKilledCount': 'sum',
    'wardPlacedCount': 'sum'
}).reset_index()

# Merge the aggregated platformGameId data with the grouped dataframe
final_df = pd.merge(grouped_df, grouped_platform_game_ids, on='handle', how='left')

# Convert players_data to a DataFrame for easy column selection and merging
df_players = pd.DataFrame(players_data)
# Merge the player_id and home_team_id columns using handle as the key
final_df = pd.merge(final_df, df_players[['handle', 'player_id', 'home_team_id']], on='handle', how='left')

# Read the teams data from the JSON file and merge the team_name column using home_team_id as the key
with open("C:\\data for lol\\esports-data\\teams.json", 'r', encoding='utf-8') as json_file:
    teams_data = json.load(json_file)
df_teams = pd.DataFrame(teams_data)
final_df = pd.merge(final_df, df_teams[['team_id', 'name']], left_on='home_team_id', right_on='team_id', how='left')

# Rename the 'name' column to 'team_name' for clarity and drop the redundant team_id column
final_df.rename(columns={'name': 'team_name'}, inplace=True)
final_df.drop(columns=['team_id'], inplace=True)

# Save the final dataframe to the specified path
final_df.to_csv('C:\\data for lol\\result chart\\final_data.csv', index=False)
