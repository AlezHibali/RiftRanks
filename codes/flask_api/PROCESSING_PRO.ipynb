# %%
import os
import json
import pandas as pd

def process_json_files(directory_path):
    # Initialize the DataFrame to store results for this directory
    df_result = pd.DataFrame()

    # Loop over each JSON file in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            with open(os.path.join(directory_path, filename), 'r') as file:
                loaded_data = json.load(file)

            # Extract game_info and ward-related entries
            game_info_entries = [entry for entry in loaded_data if entry.get("eventType") == "game_info"]
            ward_killed_entries = [entry for entry in loaded_data if entry.get("eventType") == "ward_killed"]
            ward_placed_entries = [entry for entry in loaded_data if entry.get("eventType") == "ward_placed"]

            # Initialize dictionaries for ward counts
            ward_killed_by_team = {100: 0, 200: 0}
            ward_placed_by_team = {100: 0, 200: 0}

            # Calculate ward_killed counts
            for ward_event in ward_killed_entries:
                killer_id = ward_event.get("killer")
                for entry in game_info_entries:
                    for participant in entry.get("participants", []):
                        if participant.get("participantID") == killer_id:
                            team_id = participant.get("teamID")
                            ward_killed_by_team[team_id] += 1
                            break

            # Calculate ward_placed counts
            for ward_event in ward_placed_entries:
                placer_id = ward_event.get("placer")
                for entry in game_info_entries:
                    for participant in entry.get("participants", []):
                        if participant.get("participantID") == placer_id:
                            team_id = participant.get("teamID")
                            ward_placed_by_team[team_id] += 1
                            break

            # Extract the platformGameId
            platformGameId = None
            for entry in loaded_data:
                if entry.get("eventType") == "game_info":
                    platformGameId = entry.get("platformGameId")
                    break

            # Process the loaded data
            results = {
                'platformGameId': platformGameId,
                'building_destroyed': {},
                'champion_kill': {},
                'baron_kill': {},
                'riftHerald_kill': {},
                'dragon_kill': {},
                'game_end': {},
                'first_baron_team': None,
                'first_riftHerald_team': None
            }

            first_baron_time = float('inf')
            first_riftHerald_time = float('inf')

            for event in loaded_data:
                event_type = event.get("eventType")
                if event_type == "building_destroyed":
                    team_id = event["teamID"]
                    results['building_destroyed'][team_id] = results['building_destroyed'].get(team_id, 0) + 1
                elif event_type == "champion_kill":
                    killer_team_id = event["killerTeamID"]
                    results['champion_kill'][killer_team_id] = results['champion_kill'].get(killer_team_id, 0) + 1
                elif event_type == "epic_monster_kill":
                    monster_type = event.get("monsterType")
                    killer_team_id = event["killerTeamID"]
                    if monster_type == "baron":
                        results['baron_kill'][killer_team_id] = results['baron_kill'].get(killer_team_id, 0) + 1
                        if event["gameTime"] < first_baron_time:
                            first_baron_time = event["gameTime"]
                            results['first_baron_team'] = killer_team_id
                    elif monster_type == "riftHerald":
                        results['riftHerald_kill'][killer_team_id] = results['riftHerald_kill'].get(killer_team_id, 0) + 1
                        if event["gameTime"] < first_riftHerald_time:
                            first_riftHerald_time = event["gameTime"]
                            results['first_riftHerald_team'] = killer_team_id
                    elif monster_type == "dragon":
                        results['dragon_kill'][killer_team_id] = results['dragon_kill'].get(killer_team_id, 0) + 1
                elif event_type == "game_end":
                    winning_team_id = event.get("winningTeam")
                    results['game_end'][winning_team_id] = results['game_end'].get(winning_team_id, 0) + 1

            # Transform the results into a DataFrame
            data = {
                'platformGameId': [],
                'teamID': [],
                'building_destroyed': [],
                'destroyed_opponent_buildings': [],
                'champion_kill': [],
                'baron_kill': [],
                'riftHerald_kill': [],
                'dragon_kill': [],
                'first_baron_team': [],
                'first_riftHerald_team': [],
                'game_end': []
            }

            all_teams = set(list(results['building_destroyed'].keys()) + list(results['champion_kill'].keys()) +
                            list(results['baron_kill'].keys()) + list(results['riftHerald_kill'].keys()) +
                            list(results['game_end'].keys()) + list(results['dragon_kill'].keys()))

            for team_id in all_teams:
                data['platformGameId'].append(platformGameId)
                data['teamID'].append(team_id)
                data['building_destroyed'].append(results['building_destroyed'].get(team_id, 0))
                opponent_team_id = [tid for tid in all_teams if tid != team_id][0]  # Assuming only two teams
                data['destroyed_opponent_buildings'].append(results['building_destroyed'].get(opponent_team_id, 0))
                data['champion_kill'].append(results['champion_kill'].get(team_id, 0))
                data['baron_kill'].append(results['baron_kill'].get(team_id, 0))
                data['riftHerald_kill'].append(results['riftHerald_kill'].get(team_id, 0))
                data['dragon_kill'].append(results['dragon_kill'].get(team_id, 0))
                data['first_baron_team'].append(1 if team_id == results['first_baron_team'] else 0)
                data['first_riftHerald_team'].append(1 if team_id == results['first_riftHerald_team'] else 0)
                data['game_end'].append(results['game_end'].get(team_id, 0))

            df = pd.DataFrame(data)
            # Append ward data to the DataFrame
            for team_id in [100, 200]:
                df.loc[df['teamID'] == team_id, 'ward_killed'] = ward_killed_by_team[team_id]
                df.loc[df['teamID'] == team_id, 'ward_placed'] = ward_placed_by_team[team_id]

            # Append the DataFrame to df_result
            df_result = pd.concat([df_result, df], ignore_index=True)

    return df_result

# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO

S3_BUCKET_URL = "https://power-rankings-dataset-gprhack.s3.us-west-2.amazonaws.com"

def download_gzip_and_write_to_json(file_name):
    local_file_name = file_name.replace(":", "_")
    # If file already exists locally do not re-download game
    if os.path.isfile(f"{local_file_name}.json"):
        return

    response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
    if response.status_code == 200:
        try:
            gzip_bytes = BytesIO(response.content)
            with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
                with open(f"{local_file_name}.json", 'wb') as output_file:
                    shutil.copyfileobj(gzipped_file, output_file)
                print(f"{file_name}.json written")
        except Exception as e:
            print("Error:", e)
    else:
        print(f"Failed to download {file_name}")

def download_esports_files():
    directory = "esports-data"
    if not os.path.exists(directory):
        os.makedirs(directory)

    esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data"]
    for file_name in esports_data_files:
        download_gzip_and_write_to_json(f"{directory}/{file_name}")

def download_games(year,max_game = 250):
    start_time = time.time()
    game_number = 100
    master_df = pd.DataFrame()
    with open("esports-data/tournaments.json", "r") as json_file:
        tournaments_data = json.load(json_file)
    with open("esports-data/mapping_data.json", "r") as json_file:
        mappings_data = json.load(json_file)

    directory = "games"
    if not os.path.exists(directory):
        os.makedirs(directory)

    mappings = {
        esports_game["esportsGameId"]: esports_game for esports_game in mappings_data
    }

    game_counter = 0
    int_game_counter = 0

    for tournament in tournaments_data:
        start_date = tournament.get("startDate", "")
        if start_date.startswith(str(year)):
            print(f"Processing {tournament['slug']}")
            for stage in tournament["stages"]:
                for section in stage["sections"]:
                    for match in section["matches"]:
                        for game in match["games"]:
                            if game["state"] == "completed":
                                try:
                                    platform_game_id = mappings[game["id"]]["platformGameId"]
                                except KeyError:
                                    print(f"{game['id']} not found in the mapping table")
                                    continue

                                download_gzip_and_write_to_json(f"{directory}/{platform_game_id}")
                                game_counter += 1
                                int_game_counter += 1
                            
                            # Exit condition once max_games have been processed
                            if int_game_counter >= game_number:
                                int_game_counter = 0 
                                directory = "C:\\data for lol\\code\\games"
                                master_df = pd.concat([master_df, process_json_files(directory)], ignore_index=True)
                                print("data process complete\n")
                                for filename in os.listdir(directory):
                                    file_path = os.path.join(directory, filename)
                                    
                                    # Check if it's a file
                                    if os.path.isfile(file_path):
                                        os.remove(file_path)  # Delete the file
                                print("data delete complete\n")

                            if game_counter % 10 == 0:
                                print(
                                    f"----- Processed {game_counter} games, current run time: \
                                    {round((time.time() - start_time)/60, 2)} minutes"
                                )
                            if game_counter > max_game: 
                                print("1000 complete\n")
                                return
                                        
                                
    master_df.to_csv("C:\\data for lol\\result chart\\master_consolidated_data.csv", index=False)

if __name__ == "__main__":
    download_esports_files()
    download_games(2023)
# Out:
# esports-data/leagues.json written
# esports-data/tournaments.json written
# esports-data/players.json written
# esports-data/teams.json written
# esports-data/mapping_data.json written
# Processing nacl_qualifiers_2_summer_2023
# games/ESPORTSTMNT03:3196037.json written
# games/ESPORTSTMNT03:3196049.json written
# games/ESPORTSTMNT03:3196058.json written
# games/ESPORTSTMNT03:3197014.json written
# games/ESPORTSTMNT03:3198185.json written
# games/ESPORTSTMNT03:3200156.json written
# games/ESPORTSTMNT03:3199178.json written
# games/ESPORTSTMNT03:3198199.json written
# games/ESPORTSTMNT03:3200168.json written
# games/ESPORTSTMNT03:3198544.json written
# ----- Processed 10 games, current run time:                                     0.37 minutes
# games/ESPORTSTMNT03:3198546.json written
# games/ESPORTSTMNT03:3195064.json written
# games/ESPORTSTMNT03:3196051.json written
# games/ESPORTSTMNT03:3196057.json written
# 110733838936446954 not found in the mapping table
# games/ESPORTSTMNT03:3197025.json written
# games/ESPORTSTMNT03:3198183.json written
# games/ESPORTSTMNT03:3199172.json written
# games/ESPORTSTMNT03:3198196.json written
# games/ESPORTSTMNT03:3200165.json written
# games/ESPORTSTMNT03:3198206.json written
# ----- Processed 20 games, current run time:                                     0.68 minutes
# games/ESPORTSTMNT03:3198553.json written
# games/ESPORTSTMNT03:3199526.json written
# games/ESPORTSTMNT03:3199528.json written
# games/ESPORTSTMNT03:3195262.json written
# games/ESPORTSTMNT03:3197195.json written
# games/ESPORTSTMNT03:3197205.json written
# games/ESPORTSTMNT03:3195300.json written
# games/ESPORTSTMNT03:3198294.json written
# games/ESPORTSTMNT03:3199274.json written
# games/ESPORTSTMNT03:3198298.json written
# ----- Processed 30 games, current run time:                                     1.05 minutes
# games/ESPORTSTMNT03:3198299.json written
# games/ESPORTSTMNT03:3200543.json written
# games/ESPORTSTMNT03:3199525.json written
# games/ESPORTSTMNT03:3197182.json written
# games/ESPORTSTMNT03:3195276.json written
# games/ESPORTSTMNT03:3195306.json written
# games/ESPORTSTMNT03:3196275.json written
# games/ESPORTSTMNT03:3198292.json written
# games/ESPORTSTMNT03:3198296.json written
# 110733838936447001 not found in the mapping table
# 110733838936447002 not found in the mapping table
# games/ESPORTSTMNT03:3200536.json written
# ----- Processed 40 games, current run time:                                     1.35 minutes
# games/ESPORTSTMNT03:3200539.json written
# games/ESPORTSTMNT03:3199520.json written
# games/ESPORTSTMNT03:3198611.json written
# games/ESPORTSTMNT03:3200605.json written
# games/ESPORTSTMNT03:3198621.json written
# games/ESPORTSTMNT03:3200613.json written
# games/ESPORTSTMNT03:3200614.json written
# games/ESPORTSTMNT03:3198612.json written
# games/ESPORTSTMNT03:3200607.json written
# games/ESPORTSTMNT03:3200609.json written
# ----- Processed 50 games, current run time:                                     1.62 minutes
# games/ESPORTSTMNT03:3198622.json written
# games/ESPORTSTMNT03:3198623.json written
# games/ESPORTSTMNT03:3198727.json written
# games/ESPORTSTMNT03:3198737.json written
# games/ESPORTSTMNT03:3199703.json written
# games/ESPORTSTMNT03:3198740.json written
# games/ESPORTSTMNT03:3200718.json written
# games/ESPORTSTMNT03:3198741.json written
# games/ESPORTSTMNT03:3198743.json written
# games/ESPORTSTMNT03:3200722.json written
# ----- Processed 60 games, current run time:                                     1.95 minutes
# games/ESPORTSTMNT03:3198744.json written
# Processing gll_summer_2023
# games/ESPORTSTMNT01:3383508.json written
# games/ESPORTSTMNT03:3166207.json written
# games/ESPORTSTMNT03:3166463.json written
# games/ESPORTSTMNT01:3369750.json written
# games/ESPORTSTMNT01:3373407.json written
# games/ESPORTSTMNT03:3166786.json written
# games/ESPORTSTMNT01:3385039.json written
# games/ESPORTSTMNT01:3370824.json written
# games/ESPORTSTMNT03:3165797.json written
# ----- Processed 70 games, current run time:                                     2.3 minutes
# games/ESPORTSTMNT03:3167447.json written
# games/ESPORTSTMNT01:3383851.json written
# games/ESPORTSTMNT01:3374235.json written
# games/ESPORTSTMNT03:3167097.json written
# games/ESPORTSTMNT01:3382983.json written
# games/ESPORTSTMNT03:3165885.json written
# games/ESPORTSTMNT03:3166491.json written
# games/ESPORTSTMNT01:3383466.json written
# games/ESPORTSTMNT01:3372328.json written
# games/ESPORTSTMNT01:3373365.json written
# ----- Processed 80 games, current run time:                                     2.65 minutes
# games/ESPORTSTMNT01:3382512.json written
# games/ESPORTSTMNT03:3166149.json written
# games/ESPORTSTMNT01:3369698.json written
# games/ESPORTSTMNT03:3166123.json written
# games/ESPORTSTMNT01:3385015.json written
# games/ESPORTSTMNT01:3384405.json written
# games/ESPORTSTMNT01:3371651.json written
# games/ESPORTSTMNT03:3165840.json written
# games/ESPORTSTMNT03:3167347.json written
# games/ESPORTSTMNT01:3390879.json written
# ----- Processed 90 games, current run time:                                     2.96 minutes
# games/ESPORTSTMNT03:3185548.json written
# games/ESPORTSTMNT03:3184143.json written
# games/ESPORTSTMNT03:3176620.json written
# games/ESPORTSTMNT03:3176286.json written
# games/ESPORTSTMNT03:3180760.json written
# games/ESPORTSTMNT01:3389698.json written
# games/ESPORTSTMNT03:3174697.json written
# 110428723805336981 not found in the mapping table
# games/ESPORTSTMNT03:3185169.json written
# games/ESPORTSTMNT01:3390584.json written
# games/ESPORTSTMNT03:3176207.json written
# data process complete
#
# data delete complete
#
# ----- Processed 100 games, current run time:                                     5.4 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3185523
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3390621
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3182799
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3185130
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3391036
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3176234
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3176263
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3389839
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3184549
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3174629
# ----- Processed 110 games, current run time:                                     5.49 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3183492
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3388808
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3390833
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3176526
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3182739
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3184119
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3191737
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3190842
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3189910
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3191822
# ----- Processed 120 games, current run time:                                     5.58 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3190919
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2822208
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2822219
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2822222
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3195550
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3195570
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3197538
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3195598
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3407892
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3409803
# ----- Processed 130 games, current run time:                                     5.66 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3409822
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3408868
# Failed to download C:\data for lol\code\games/ESPORTSTMNT01:3409862
# Processing elite_series_summer_2023
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683951
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2684716
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683305
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2685161
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3165542
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2687267
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2815913
# ----- Processed 140 games, current run time:                                     5.75 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683130
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2815885
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683276
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2687281
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683788
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3167423
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2687237
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3166521
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2685298
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2817904
# ----- Processed 150 games, current run time:                                     5.83 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683967
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2685748
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2685917
# Failed to download C:\data for lol\code\games/ESPORTSTMNT03:3165613
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2685151
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2816865
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2684919
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2686273
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683108
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2684736
# ----- Processed 160 games, current run time:                                     5.92 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2683289
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2823164
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2818761
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2818579
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2819277
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2687428
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2821265
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2820108
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2820286
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2819141
# ----- Processed 170 games, current run time:                                     6.0 minutes
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2818607
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2821256
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2820740
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2686417
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2823263
# Failed to download C:\data for lol\code\games/ESPORTSTMNT04:2688427
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2820544
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2819124
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2822185
# Failed to download C:\data for lol\code\games/ESPORTSTMNT06:2819752
# ----- Processed 180 games, current run time:                                     6.09 minutes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 106
#     104 if __name__ == "__main__":
#     105     download_esports_files()
# --> 106     download_games(2023)
#
# Cell In[5], line 74, in download_games(year, max_game)
#      71     print(f"{game['id']} not found in the mapping table")
#      72     continue
# ---> 74 download_gzip_and_write_to_json(f"{directory}/{platform_game_id}")
#      75 game_counter += 1
#      76 int_game_counter += 1
#
# Cell In[5], line 17, in download_gzip_and_write_to_json(file_name)
#      14 if os.path.isfile(f"{local_file_name}.json"):
#      15     return
# ---> 17 response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
#      18 if response.status_code == 200:
#      19     try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1090 # Force connect early to allow us to validate the connection.
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#    1095     warnings.warn(
#    1096         (
#    1097             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1102         InsecureRequestWarning,
#    1103     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:444, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     442 if ca_certs or ca_cert_dir or ca_cert_data:
#     443     try:
# --> 444         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     445     except OSError as e:
#     446         raise SSLError(e) from e
#
# KeyboardInterrupt:
